# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Make-quick-plots" data-toc-modified-id="Make-quick-plots-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Make quick plots</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Make-multiple-plots-in-one-figure" data-toc-modified-id="Make-multiple-plots-in-one-figure-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Make multiple plots in one figure</a></span></li></ul></li></ul></li><li><span><a href="#Object-oriented-interface" data-toc-modified-id="Object-oriented-interface-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Object-oriented interface</a></span><ul class="toc-item"><li><span><a href="#How-to-make-ax" data-toc-modified-id="How-to-make-ax-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>How to make ax</a></span></li><li><span><a href="#Make-subplots-use-subplots-method" data-toc-modified-id="Make-subplots-use-subplots-method-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Make subplots use subplots method</a></span></li><li><span><a href="#Axes-method" data-toc-modified-id="Axes-method-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Axes method</a></span><ul class="toc-item"><li><span><a href="#Legend-inferred-from-data" data-toc-modified-id="Legend-inferred-from-data-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Legend inferred from data</a></span></li><li><span><a href="#Custom-Legend" data-toc-modified-id="Custom-Legend-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Custom Legend</a></span></li><li><span><a href="#Line-style-method" data-toc-modified-id="Line-style-method-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Line style method</a></span></li><li><span><a href="#Color-method" data-toc-modified-id="Color-method-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Color method</a></span></li><li><span><a href="#Marker-method" data-toc-modified-id="Marker-method-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Marker method</a></span></li><li><span><a href="#Grid" data-toc-modified-id="Grid-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>Grid</a></span></li><li><span><a href="#Axis" data-toc-modified-id="Axis-2.3.7"><span class="toc-item-num">2.3.7&nbsp;&nbsp;</span>Axis</a></span></li><li><span><a href="#Set-limit" data-toc-modified-id="Set-limit-2.3.8"><span class="toc-item-num">2.3.8&nbsp;&nbsp;</span>Set limit</a></span></li><li><span><a href="#Set-ticks" data-toc-modified-id="Set-ticks-2.3.9"><span class="toc-item-num">2.3.9&nbsp;&nbsp;</span>Set ticks</a></span></li><li><span><a href="#Set-twin-axis" data-toc-modified-id="Set-twin-axis-2.3.10"><span class="toc-item-num">2.3.10&nbsp;&nbsp;</span>Set twin axis</a></span></li></ul></li><li><span><a href="#histogram" data-toc-modified-id="histogram-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>histogram</a></span></li><li><span><a href="#Scatter" data-toc-modified-id="Scatter-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Scatter</a></span></li><li><span><a href="#Contour" data-toc-modified-id="Contour-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Contour</a></span></li><li><span><a href="#one-example" data-toc-modified-id="one-example-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>one example</a></span></li></ul></li><li><span><a href="#Examples" data-toc-modified-id="Examples-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Examples</a></span><ul class="toc-item"><li><span><a href="#Add-a-single-point,-single-horizontal,-vertial-line" data-toc-modified-id="Add-a-single-point,-single-horizontal,-vertial-line-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Add a single point, single horizontal, vertial line</a></span></li></ul></li></ul></div>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
# Ref1:
# https://www.pythonpool.com/matplotlib-text/#:~:text=Matplotlib%20text%20in%20Python%20can%20also%20be%20added,text%20as%20a%20title%20at%20the%20figure%E2%80%99s%20center.

# %% [markdown]
# # Make quick plots

# %%
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)

# %% [markdown]
# What plot does, is to use 2-d array, and plots
# $(x_1, y_1), (x_2, y_2), ..., (x_n, y_n)$

# %% [markdown]
# Let's make the title and label

# %%
plt.plot(x,y)

plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')
# Out:
# Text(0.5, 1.0, 'sine wave')

# %%
# plt.show() # it's not needed in jupyter notebook, but required if it's not in jupyter notebook.

# %% [markdown]
# ### Make multiple plots in one figure

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

# %% [markdown]
# # Object-oriented interface

# %% [markdown]
# While it is easy to quickly generate plots with the matplotlib.pyplot module, the use of object-oriented approach is recommended as it gives more control and customization of your plots. Most of the functions are also available in the matplotlib.axes.Axes class.
#
# The main idea behind using the more formal object-oriented method is to create figure objects and then just call methods or attributes off of that object. This approach helps better in dealing with a canvas that has multiple plots on it.
#
# In object-oriented interface, Pyplot is used only for a few functions such as figure creation, and the user explicitly creates and keeps track of the figure and axes objects. At this level, the user uses Pyplot to create figures, and through those figures, one or more axes objects can be created. These axes objects are then used for most plotting actions.
#
# To begin with, we create a figure instance which provides an empty canvas.

# %% [markdown]
# ## How to make ax

# %% [markdown]
# 	注意，一般都有两种方法建立axes
# 	fig = plt.figure()
#
# 	ax = fig.add_axes([x0, y0, width, height]) # method-1, create absolute axes, note, this will lead to issues such as not enough space for ticks, all the numbers are between [0, 1].
#
# 	ax = fig.add_subplot(rcn) # r--> row number, c --> column number, n --> current plot position
#
# 	ax = fig.add_subplot(111) # do you think this is equivalent to add_axes([0,0,1,1])? No, this is actually equal to [0.125,0.11,0.775,0.77], some spaces are reserved for ticks, labels, etc.
#
# 	The preferred method is:
#
# 	fig, ax = plt.subplots(1, 3) # ax will be an array, to access them, use ax[0], ax[1], ax[2]; if we have a 2d array, then we need do ax[0][0] for first subplots

# %%
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title("sine wave")
ax.set_xlabel('angle')
ax.set_ylabel('sine')
ax.plot(x,y)

# plt.show()

# %% [markdown]
# ## Make subplots use subplots method

# %%
x = np.linspace(0, 2, 100)
fig, ax = plt.subplots(1,3)

ax[0].plot(x, x, label='line')
ax[0].set_title("fig1")
ax[1].plot(x, x**2)
ax[1].set_title("fig2")
ax[2].plot(x, x**3)
ax[2].set_title("fig3")
# Out:
# Text(0.5, 1.0, 'fig3')

# %% [markdown]
# ## Axes method

# %% [markdown]
# ### Legend inferred from data

# %% [markdown]
# The easiest way to do this is to just give the lines labels, then call legend with default method.
#
# The syntax is
#
# ax.legend(handles, labels, loc) # all the parameters can be omitted

# %%
x = np.linspace(0, 20, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, "-b", label="sine") # note, legend has to have "label", otherwise, it won't show up
plt.plot(x, y2, "-r", label="cosine")
plt.legend(loc="upper left") # here, loc is used

# %% [markdown]
# ### Custom Legend

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

legend_elements = [Line2D([0], [0], color='b', lw=4, label='Line'),
                   Line2D([0], [0], marker='o', color='w', label='Scatter',
                          markerfacecolor='g', markersize=15),
                   Patch(facecolor='orange', edgecolor='r',
                         label='Color Patch')]

# Create the figure
fig, ax = plt.subplots()
x = np.linspace(0, 20, 1000)
ax.legend(handles=legend_elements, loc='center')
ax.plot(x, x**2,color='y', linestyle='dashed')

# %% [markdown]
# ### Line style method

# %% [markdown]
# Using **linestyle** Argument:
#
# - Solid
# - Dashed
# - Dotted
# - Dashdot
# - None

# %% [markdown]
# ### Color method

# %% [markdown]
# Use **color** argument
# - 'b' as blue
# - 'g' as green
# - 'r' as red
# - 'c' as cyan
# - 'm' as magenta
# - 'y' as yellow
# - 'k' as black
# - 'w' as white

# %% [markdown]
# ### Marker method

# %% [markdown]
# use **marker** argument
# - '.' point
# - 'o' circle
# - 's' square
# - '+' plus
#
# etc

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
# Create the figure
fig, ax = plt.subplots()
x = np.linspace(0, 20, 1000)
ax.plot(x, x**2, color='y',linestyle='dashed')

# %% [markdown]
# ### Grid

# %%
#fig, axes = plt.subplots(1,3, figsize = (12,4)) # fig size default is (6.4, 4.8)
fig, axes = plt.subplots(1,3, figsize=(15, 5)) # fig size default is (6.4, 4.8) --> (width, height)

x = np.arange(1,11)
axes[0].plot(x, x**3, 'g',lw=2)
axes[0].grid(True)  # display
axes[0].set_title('default grid')
axes[1].plot(x, np.exp(x), 'r')
axes[1].grid(color='b', ls = '-.', lw = 0.25) # specify more details of the grid
axes[1].set_title('custom grid')
axes[2].plot(x,x)  # no grid! default is false
axes[2].set_title('no grid')
# Out:
# Text(0.5, 1.0, 'no grid')

# %% [markdown]
# ### Axis

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
x = np.arange(1,5)
axes[0].plot( x, np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal scale")
axes[1].plot (x, np.exp(x))
axes[1].plot(x, x**2)
axes[1].set_yscale("log") # the plot will use log_10 as the y axis unit
axes[1].set_title("Logarithmic scale (y)")
axes[0].set_xlabel("x axis")
axes[0].set_ylabel("y axis")
axes[0].xaxis.labelpad = 20 # the distance from the label to x-axis
axes[1].set_xlabel("x axis")
axes[1].set_ylabel("y axis")
plt.show()

# %% [markdown]
# ### Set limit

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
x = np.arange(1,5)
axes[0].plot( x, np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal scale")
axes[1].plot (x, np.exp(x))
axes[1].plot(x, x**2)
axes[1].set_yscale("log") # the plot will use log_10 as the y axis unit
axes[1].set_title("Logarithmic scale (y)")
axes[0].set_xlabel("x axis")
axes[0].set_ylabel("y axis")
axes[0].xaxis.labelpad = 20 # the distance from the label to x-axis
axes[1].set_xlabel("x axis")
axes[1].set_ylabel("y axis")
# new line
axes[0].set_ylim(0,100)
axes[0].set_xlim(0,10)


plt.show()

# %% [markdown]
# ### Set ticks

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
x = np.arange(1,5)
axes[0].plot( x, np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal scale")
axes[1].plot (x, np.exp(x))
axes[1].plot(x, x**2)
axes[1].set_yscale("log") # the plot will use log_10 as the y axis unit
axes[1].set_title("Logarithmic scale (y)")
axes[0].set_xlabel("x axis")
axes[0].set_ylabel("y axis")
axes[0].xaxis.labelpad = 20 # the distance from the label to x-axis
axes[1].set_xlabel("x axis")
axes[1].set_ylabel("y axis")
# new line
axes[0].set_ylim(0,100)
axes[0].set_xlim(0,10)
axes[0].set_xticks([0,5, 10])
axes[0].set_xticklabels(['zero','five','ten',])
axes[0].set_yticks([0,40,80])
axes[0].set_yticklabels(['zero','forty','eighty',])

plt.show()

# %% [markdown]
# ### Set twin axis

# %% [markdown]
# It is considered useful to have dual x or y axes in a figure. Moreso, when plotting curves with different units together. Matplotlib supports this with the twinxand twiny functions.
#
# In the following example, the plot has dual y axes, one showing exp(x) and the other showing log(x)

# %%
fig = plt.figure()
a1 = fig.add_axes([0,0,1,1])
x = np.arange(1,11)
a1.plot(x,np.exp(x))
a1.set_ylabel('exp')
a2 = a1.twinx() # key is here
a2.plot(x, np.log(x),'ro-')
a2.set_ylabel('log')
fig.legend(labels = ('exp','log'),loc='upper left')
plt.show()

# %% [markdown]
# ## histogram

# %%
fig,ax = plt.subplots(1,1)
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
ax.hist(a, bins = [0,25,50,75,100])
ax.set_title("histogram of result")
ax.set_xticks([0,25,50,75,100])
ax.set_xlabel('marks')
ax.set_ylabel('no. of students')
plt.show()

# %% [markdown]
# note, when you add density, you may think this is "NOT" normalized, however, this is not true..
#
# density*width is the number!

# %% [markdown]
# What makes you think it is not normalised? At a guess, it's probably because the heights of each column extend to values greater than 1. However, this thinking is flawed because in a normalised histogram/pdf, the total area under it should sum to one (not the heights). When you are dealing with small steps in x (as you are), that are less than one, then it is not surprising that the column heights are greater than one!
#
# You can see this clearly in the scipy example you link: the x-values are much greater (by an order of magnitude) so it follows that their y-values are also smaller. You will see the same effect if you change your distribution to cover a wider range of values. Try a sigma of 10 instead of 0.1, see what happens!

# %% [markdown]
# ## Scatter

# %%
np.random.seed(1)

# %%
mu, sigma = 1, 2
scale = 0.1
size = 25
x = np.random.normal(mu, sigma, size=(size,))
e = np.random.normal(0, sigma*scale, size=(len(x),))

slope, intercept = 1.3, 0
fig, ax = plt.subplots(1,1, figsize=(6,6))
y = slope * x + intercept + e
ax.scatter(x, y, color='r', label="y vs x")
ax.set_title("linear regression")
ax.set_xlabel("X")
ax.set_ylabel("Y = slope*X + error")
ax.set_xlim(-2, 6)
ax.set_ylim(-3, 7)
ax.set_xticks([-2, 0, 2, 4, 6])
ax.set_yticks([-2, 0, 2, 4, 6])
ax.legend()
plt.show()

# %% [markdown]
# ## Contour

# %% [markdown]
# - X, Y: These parameter are the coordinates of the values in Z.
# - Z : This parameter is the height values over which the contour is drawn.
# - levels :
#     - levelsint or array-like, optional
#     - Determines the number and positions of the contour lines / regions.
#     - If an int n, use MaxNLocator, which tries to automatically choose no more than n+1 "nice" contour levels between vmin and vmax.
#     - If array-like, draw contour lines at the specified levels. The values must be in increasing order.
#     - Suppose we have levels=[a], this is to draw Z=a

# %%
xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist) # note, X.shape = (100, 100), Y.shape = (100, 100)

Z = np.sqrt(X**2 + Y**2) # note Z.shape = (100, 100)
fig,ax=plt.subplots(1,3, figsize=(20, 5))
cp = ax[0].contourf(X, Y, Z)
fig.colorbar(cp, ax=ax[0]) # Add a colorbar to a plot
ax[0].set_title('Filled Contours Plot')
#ax.set_xlabel('x (cm)')
ax[0].set_ylabel('y (cm)')

# make the second plot, with levels
#Z = np.ones(len(X))
cp2 = ax[1].contour(X, Y, Z)

# if we only show one level
cp2 = ax[2].contour(X, Y, Z, levels=[1])

plt.show()

# %% [markdown]
# ## one example

# %% [markdown]
# We will show in origianl coordinate $x^2 + y^2 = 1$ and how it is transformed after a linear matrix $A = [[1,1], [0,1]]$

# %%
x = np.linspace(-1.0, 1.0, 100)

y_pos = np.sqrt(1- x**2)
y_neg = -np.sqrt(1- x**2)

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5))
ax.plot(x, y_pos)
ax.plot(x, y_neg)
plt.show()

# %%
def plot_2d_matrix(A, xlim=None, ylim=None):
    x = np.linspace(-1.0, 1.0, 100)

    y_pos = np.sqrt(1- x**2)
    y_neg = -np.sqrt(1- x**2)
    x_new_pos, y_new_pos = [], []
    for i in zip(x, y_pos):
        temp = np.array(i).reshape(2,1)
        new_vec = np.matmul(A, temp)
        #print(new_vec)
        x_new_pos.append(new_vec[0][0])
        y_new_pos.append(new_vec[1][0])
        #break

    x_new_neg, y_new_neg = [], []
    for i in zip(x, y_neg):
        temp = np.array(i).reshape(2,1)
        new_vec = np.matmul(A, temp)
        #print(new_vec)
        x_new_neg.append(new_vec[0][0])
        y_new_neg.append(new_vec[1][0])

    fig, ax = plt.subplots(1,1, figsize=(5,5))
    ax.plot(x_new_pos, y_new_pos)
    ax.plot(x_new_neg, y_new_neg)
    if xlim is None and ylim is None:
        ax.set_ylim(-3,3)
        ax.set_xlim(-3,3)
    else:
        ax.set_ylim(ylim[0], ylim[1])
        ax.set_xlim(xlim[0], xlim[1])
    plt.show()

# %%
#A = np.array([[1,2], [0.5,1]]) # make it straignt, page 147 (zhongwen)
#A = np.array([[0,-1], [1,0]]) # rotation by +45
A = np.array([[2,2], [-1,1]]) # page 354 example, Gilbert

#A = np.array([[3,0], [0,3]]) # scale by 3

#A = np.array([[1,1.5], [0,1]]) # make it ecplise, page 147 (zhongwen)
#A = np.array([[1,1], [0,1]]) # zhihu example
#A = A = np.array([[1,2], [2,1]])

plot_2d_matrix(A)

# %%
A = np.array([[2,5], [7,3]]) # page 354 example, Gilbert

plot_2d_matrix(A, xlim=[-6,6], ylim=[-10,10])

# %% [markdown]
# # Examples

# %% [markdown]
# ## Add a single point, single horizontal, vertial line

# %%
from matplotlib import pyplot as plt

x = [4]
y = [[3, 2]]
plt.xlim(0, 5)
plt.ylim(0, 5)
plt.grid()
plt.plot(x, y, marker="o", markersize=20, markeredgecolor="red", markerfacecolor="green")
plt.axvline(1, color='r')
plt.axhline(1, color='r')

plt.show()
