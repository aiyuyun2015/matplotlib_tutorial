# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Make-quick-plots" data-toc-modified-id="Make-quick-plots-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Make quick plots</a></div><div class="lev3 toc-item"><a href="#Make-multiple-plots-in-one-figure" data-toc-modified-id="Make-multiple-plots-in-one-figure-101"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Make multiple plots in one figure</a></div><div class="lev1 toc-item"><a href="#Object-oriented-interface" data-toc-modified-id="Object-oriented-interface-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Object-oriented interface</a></div><div class="lev2 toc-item"><a href="#How-to-make-ax" data-toc-modified-id="How-to-make-ax-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>How to make ax</a></div><div class="lev2 toc-item"><a href="#Make-subplots-use-subplots-method" data-toc-modified-id="Make-subplots-use-subplots-method-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Make subplots use subplots method</a></div><div class="lev2 toc-item"><a href="#Axes-method" data-toc-modified-id="Axes-method-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Axes method</a></div><div class="lev3 toc-item"><a href="#Legend-inferred-from-data" data-toc-modified-id="Legend-inferred-from-data-231"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Legend inferred from data</a></div><div class="lev3 toc-item"><a href="#Custom-Legend" data-toc-modified-id="Custom-Legend-232"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Custom Legend</a></div><div class="lev3 toc-item"><a href="#Line-style-method" data-toc-modified-id="Line-style-method-233"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Line style method</a></div><div class="lev3 toc-item"><a href="#Color-method" data-toc-modified-id="Color-method-234"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Color method</a></div><div class="lev3 toc-item"><a href="#Marker-method" data-toc-modified-id="Marker-method-235"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Marker method</a></div><div class="lev3 toc-item"><a href="#Grid" data-toc-modified-id="Grid-236"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>Grid</a></div><div class="lev3 toc-item"><a href="#Axis" data-toc-modified-id="Axis-237"><span class="toc-item-num">2.3.7&nbsp;&nbsp;</span>Axis</a></div><div class="lev3 toc-item"><a href="#Set-limit" data-toc-modified-id="Set-limit-238"><span class="toc-item-num">2.3.8&nbsp;&nbsp;</span>Set limit</a></div><div class="lev3 toc-item"><a href="#Set-ticks" data-toc-modified-id="Set-ticks-239"><span class="toc-item-num">2.3.9&nbsp;&nbsp;</span>Set ticks</a></div><div class="lev3 toc-item"><a href="#Set-twin-axis" data-toc-modified-id="Set-twin-axis-2310"><span class="toc-item-num">2.3.10&nbsp;&nbsp;</span>Set twin axis</a></div>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
# # Make quick plots

# %%
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)

# %% [markdown]
# What plot does, is to use 2-d array, and plots
# $(x_1, y_1), (x_2, y_2), ..., (x_n, y_n)$

# %% [markdown]
# Let's make the title and label

# %%
plt.plot(x,y)

plt.xlabel("angle")
plt.ylabel("sine")
plt.title('sine wave')
# Out:
# Text(0.5, 1.0, 'sine wave')

# %%
# plt.show() # it's not needed in jupyter notebook, but required if it's not in jupyter notebook.

# %% [markdown]
# ### Make multiple plots in one figure

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

# %% [markdown]
# # Object-oriented interface

# %% [markdown]
# While it is easy to quickly generate plots with the matplotlib.pyplot module, the use of object-oriented approach is recommended as it gives more control and customization of your plots. Most of the functions are also available in the matplotlib.axes.Axes class.
#
# The main idea behind using the more formal object-oriented method is to create figure objects and then just call methods or attributes off of that object. This approach helps better in dealing with a canvas that has multiple plots on it.
#
# In object-oriented interface, Pyplot is used only for a few functions such as figure creation, and the user explicitly creates and keeps track of the figure and axes objects. At this level, the user uses Pyplot to create figures, and through those figures, one or more axes objects can be created. These axes objects are then used for most plotting actions.
#
# To begin with, we create a figure instance which provides an empty canvas.

# %% [markdown]
# ## How to make ax

# %% [markdown]
# 	注意，一般都有两种方法建立axes
# 	fig = plt.figure()
#
# 	ax = fig.add_axes([x0, y0, width, height]) # method-1, create absolute axes, note, this will lead to issues such as not enough space for ticks, all the numbers are between [0, 1].
#
# 	ax = fig.add_subplot(rcn) # r--> row number, c --> column number, n --> current plot position
#
# 	ax = fig.add_subplot(111) # do you think this is equivalent to add_axes([0,0,1,1])? No, this is actually equal to [0.125,0.11,0.775,0.77], some spaces are reserved for ticks, labels, etc.
#
# 	The preferred method is:
#
# 	fig, ax = plt.subplots(1, 3) # ax will be an array, to access them, use ax[0], ax[1], ax[2]; if we have a 2d array, then we need do ax[0][0] for first subplots

# %%
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title("sine wave")
ax.set_xlabel('angle')
ax.set_ylabel('sine')
ax.plot(x,y)

# plt.show()

# %% [markdown]
# ## Make subplots use subplots method

# %%
x = np.linspace(0, 2, 100)
fig, ax = plt.subplots(1,3)

ax[0].plot(x, x, label='line')
ax[0].set_title("fig1")
ax[1].plot(x, x**2)
ax[1].set_title("fig2")
ax[2].plot(x, x**3)
ax[2].set_title("fig3")
# Out:
# Text(0.5, 1.0, 'fig3')

# %% [markdown]
# ## Axes method

# %% [markdown]
# ### Legend inferred from data

# %% [markdown]
# The easiest way to do this is to just give the lines labels, then call legend with default method.
#
# The syntax is
#
# ax.legend(handles, labels, loc) # all the parameters can be omitted

# %%
x = np.linspace(0, 20, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, "-b", label="sine")
plt.plot(x, y2, "-r", label="cosine")
plt.legend(loc="upper left") # here, loc is used

# %% [markdown]
# ### Custom Legend

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

legend_elements = [Line2D([0], [0], color='b', lw=4, label='Line'),
                   Line2D([0], [0], marker='o', color='w', label='Scatter',
                          markerfacecolor='g', markersize=15),
                   Patch(facecolor='orange', edgecolor='r',
                         label='Color Patch')]

# Create the figure
fig, ax = plt.subplots()
x = np.linspace(0, 20, 1000)
ax.legend(handles=legend_elements, loc='center')
ax.plot(x, x**2,color='y', linestyle='dashed')

# %% [markdown]
# ### Line style method

# %% [markdown]
# Using **linestyle** Argument:
#
# - Solid
# - Dashed
# - Dotted
# - Dashdot
# - None

# %% [markdown]
# ### Color method

# %% [markdown]
# Use **color** argument
# - 'b' as blue
# - 'g' as green
# - 'r' as red
# - 'c' as cyan
# - 'm' as magenta
# - 'y' as yellow
# - 'k' as black
# - 'w' as white

# %% [markdown]
# ### Marker method

# %% [markdown]
# use **marker** argument
# - '.' point
# - 'o' circle
# - 's' square
# - '+' plus
#
# etc

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
# Create the figure
fig, ax = plt.subplots()
x = np.linspace(0, 20, 1000)
ax.plot(x, x**2, color='y',linestyle='dashed')

# %% [markdown]
# ### Grid

# %%
#fig, axes = plt.subplots(1,3, figsize = (12,4)) # fig size default is (6.4, 4.8)
fig, axes = plt.subplots(1,3, figsize=(15, 5)) # fig size default is (6.4, 4.8) --> (width, height)

x = np.arange(1,11)
axes[0].plot(x, x**3, 'g',lw=2)
axes[0].grid(True)  # display
axes[0].set_title('default grid')
axes[1].plot(x, np.exp(x), 'r')
axes[1].grid(color='b', ls = '-.', lw = 0.25) # specify more details of the grid
axes[1].set_title('custom grid')
axes[2].plot(x,x)  # no grid! default is false
axes[2].set_title('no grid')
# Out:
# Text(0.5, 1.0, 'no grid')

# %% [markdown]
# ### Axis

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
x = np.arange(1,5)
axes[0].plot( x, np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal scale")
axes[1].plot (x, np.exp(x))
axes[1].plot(x, x**2)
axes[1].set_yscale("log") # the plot will use log_10 as the y axis unit
axes[1].set_title("Logarithmic scale (y)")
axes[0].set_xlabel("x axis")
axes[0].set_ylabel("y axis")
axes[0].xaxis.labelpad = 20 # the distance from the label to x-axis
axes[1].set_xlabel("x axis")
axes[1].set_ylabel("y axis")
plt.show()

# %% [markdown]
# ### Set limit

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
x = np.arange(1,5)
axes[0].plot( x, np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal scale")
axes[1].plot (x, np.exp(x))
axes[1].plot(x, x**2)
axes[1].set_yscale("log") # the plot will use log_10 as the y axis unit
axes[1].set_title("Logarithmic scale (y)")
axes[0].set_xlabel("x axis")
axes[0].set_ylabel("y axis")
axes[0].xaxis.labelpad = 20 # the distance from the label to x-axis
axes[1].set_xlabel("x axis")
axes[1].set_ylabel("y axis")
# new line
axes[0].set_ylim(0,100)
axes[0].set_xlim(0,10)


plt.show()

# %% [markdown]
# ### Set ticks

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
x = np.arange(1,5)
axes[0].plot( x, np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal scale")
axes[1].plot (x, np.exp(x))
axes[1].plot(x, x**2)
axes[1].set_yscale("log") # the plot will use log_10 as the y axis unit
axes[1].set_title("Logarithmic scale (y)")
axes[0].set_xlabel("x axis")
axes[0].set_ylabel("y axis")
axes[0].xaxis.labelpad = 20 # the distance from the label to x-axis
axes[1].set_xlabel("x axis")
axes[1].set_ylabel("y axis")
# new line
axes[0].set_ylim(0,100)
axes[0].set_xlim(0,10)
axes[0].set_xticks([0,5, 10])
axes[0].set_xticklabels(['zero','five','ten',])
axes[0].set_yticks([0,40,80])
axes[0].set_yticklabels(['zero','forty','eighty',])

plt.show()

# %% [markdown]
# ### Set twin axis

# %% [markdown]
# It is considered useful to have dual x or y axes in a figure. Moreso, when plotting curves with different units together. Matplotlib supports this with the twinxand twiny functions.
#
# In the following example, the plot has dual y axes, one showing exp(x) and the other showing log(x)

# %%
fig = plt.figure()
a1 = fig.add_axes([0,0,1,1])
x = np.arange(1,11)
a1.plot(x,np.exp(x))
a1.set_ylabel('exp')
a2 = a1.twinx() # key is here
a2.plot(x, np.log(x),'ro-')
a2.set_ylabel('log')
fig.legend(labels = ('exp','log'),loc='upper left')
plt.show()
